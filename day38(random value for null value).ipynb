# %%
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
df.sample(3)
# Out:
#      Survived   Age     Fare
# 887         1  19.0  30.0000
# 702         0  18.0  14.4542
# 709         1   NaN  15.2458

# %%
df.describe()
# Out:
#          Survived         Age        Fare
# count  891.000000  714.000000  891.000000
# mean     0.383838   29.699118   32.204208
# std      0.486592   14.526497   49.693429
# min      0.000000    0.420000    0.000000
# 25%      0.000000   20.125000    7.910400
# 50%      0.000000   28.000000   14.454200
# 75%      1.000000   38.000000   31.000000
# max      1.000000   80.000000  512.329200

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']
y=pd.DataFrame(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train['Age_imputr']=x_train['Age']
x_test['Age_imputr']=x_test['Age']

# %%
x_train['Age_imputr'][x_train['Age_imputr'].isnull()]
# Out:
# 29    NaN
# 55    NaN
# 533   NaN
# 495   NaN
# 468   NaN
#        ..
# 330   NaN
# 214   NaN
# 466   NaN
# 121   NaN
# 270   NaN
# Name: Age_imputr, Length: 140, dtype: float64

# %%
x_train['Age_imputr'][x_train['Age_imputr'].isnull()]=x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
x_test['Age_imputr'][x_test['Age_imputr'].isnull()]=x_train['Age'].dropna().sample(x_test['Age'].isnull().sum()).values

# %%
x_train['Age_imputr'].isnull().sum()
# Out:
# 0

# %%
# see the distrbution
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(x_train['Age'],label='Original')
sns.distplot(x_train['Age_imputr'],label='Imputed')
plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\2953630208.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train['Age'],label='Original')
# C:\Users\raj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\2953630208.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# see the distrbution
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(x_train['Age'],label='Original',hist=False)
sns.distplot(x_train['Age_imputr'],label='Imputed',hist=False)
plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\1293705741.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train['Age'],label='Original',hist=False)
# C:\Users\raj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\1293705741.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
print("the variable varianc : ",x_train['Age'].var())
print("The variable variance: ",x_train['Age_imputr'].var())
# Out:
# the variable varianc :  210.2517072477438
# The variable variance:  218.6398013487883

# %%
x_train[['Fare','Age','Age_imputr']].cov()
# Out:
#                    Fare         Age  Age_imputr
# Fare        2700.831981   71.580633   44.011652
# Age           71.580633  210.251707  210.251707
# Age_imputr    44.011652  210.251707  218.639801

# %%
x_train[['Age','Age_imputr']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # import for using this techancal for given webside we have to get same output for given value

# %%
sampled_value = x_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sampled_value = x_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
#
# NameError: name 'observation' is not defined

# %%
data = pd.read_csv('house-train.csv',usecols=['GarageQual','FireplaceQu', 'SalePrice'])

# %%
data.sample(2)
# Out:
#     FireplaceQu GarageQual  SalePrice
# 293          TA         TA     235000
# 110         NaN         TA     136900

# %%
data.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
x=data
y=data['SalePrice']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
X_train['GarageQual_imputed'] = X_train['GarageQual']
X_test['GarageQual_imputed'] = X_test['GarageQual']

X_train['FireplaceQu_imputed'] = X_train['FireplaceQu']
X_test['FireplaceQu_imputed'] = X_test['FireplaceQu']

# %%
X_train['GarageQual_imputed'][X_train['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
X_test['GarageQual_imputed'][X_test['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values

X_train['FireplaceQu_imputed'][X_train['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_train['FireplaceQu'].isnull().sum()).values
X_test['FireplaceQu_imputed'][X_test['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_test['FireplaceQu'].isnull().sum()).values
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\856878696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['GarageQual_imputed'][X_train['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\856878696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['GarageQual_imputed'][X_test['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values
# ...

# %%
temp = pd.concat(
        [
            X_train['GarageQual'].value_counts() / len(X_train['GarageQual'].dropna()),
            X_train['GarageQual_imputed'].value_counts() / len(X_train)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

# %%
temp
# Out:
#     original   imputed
# Gd  0.487850  0.556678
# TA  0.409346  0.470258
# Fa  0.042991  0.049383
# Ex  0.033645  0.039282
# Po  0.026168  0.031425

# %%
temp = pd.concat(
        [
            X_train['FireplaceQu'].value_counts() / len(X_train['FireplaceQu'].dropna()),
            X_train['FireplaceQu_imputed'].value_counts() / len(df)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

temp
# Out:
#     original   imputed
# Gd  0.487850  0.556678
# TA  0.409346  0.470258
# Fa  0.042991  0.049383
# Ex  0.033645  0.039282
# Po  0.026168  0.031425

# %%
for category in X_train['FireplaceQu'].dropna().unique():
    sns.distplot(X_train[X_train['FireplaceQu'] == category]['SalePrice'],hist=False,label=category)
plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\1827688635.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[X_train['FireplaceQu'] == category]['SalePrice'],hist=False,label=category)
# C:\Users\raj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\1827688635.py:2: UserWarning:
#
# ...

# %%
for category in X_train['FireplaceQu_imputed'].dropna().unique():
    sns.distplot(X_train[X_train['FireplaceQu_imputed'] == category]['SalePrice'],hist=False,label=category)
plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\722808554.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[X_train['FireplaceQu_imputed'] == category]['SalePrice'],hist=False,label=category)
# C:\Users\raj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raj\AppData\Local\Temp\ipykernel_14728\722808554.py:2: UserWarning:
#
# ...
