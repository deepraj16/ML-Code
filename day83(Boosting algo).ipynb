# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# making the Data set so that we can work on data

# %%
np.random.seed(42)
X=np.random.rand(100,1) -0.5 
y=3 *X[:,0]**2 + 0.05 * np.random.randn(100)

# %%
df=pd.DataFrame()

# %%
df['X']=X.reshape(100)
df['y']=y

# %%
df.sample(4)
# Out:
#            X         y
# 76  0.271270  0.186762
# 83 -0.436442  0.604272
# 80  0.363103  0.488821
# 98 -0.474581  0.689516

# %%
sns.scatterplot(df,x='X',y='y')
plt.title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
# 3 model 
df['pred1']=df['y'].mean()
df.sample()
# Out:
#            X         y     pred1
# 17  0.024756 -0.014544  0.265458

# %%
df['res1']=df['y'] - df['pred1']

# %%
# prediction -1 
sns.scatterplot(df,x='X',y='y')
plt.plot(df['X'],df['pred1'],color='red')

# %%
df.sample(4)
# Out:
#            X         y     pred1      res1
# 21 -0.360506  0.402947  0.265458  0.137488
# 14 -0.318175  0.308560  0.265458  0.043102
# 47  0.020068 -0.068884  0.265458 -0.334343
# 19 -0.208771  0.057580  0.265458 -0.207878

# %%
from sklearn.tree import DecisionTreeRegressor 
clf2=DecisionTreeRegressor(max_leaf_nodes=8)
clf2.fit(df['X'].values.reshape(100,1),df['res1'].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
from sklearn.tree import plot_tree 
plot_tree(clf2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X_test = np.linspace(-0.5,0.5,100)

# %%
y_pred2 = 0.267 + clf2.predict(df['X'].values.reshape(100,1))

# %%
df['pred2']=y_pred2

# %%
plt.plot(X_test,y_pred,color='red')
sns.scatterplot(df,x='X',y='y')
# Out:
# <Axes: xlabel='X', ylabel='y'>

# %%
tree2 =DecisionTreeRegressor(max_leaf_nodes=8)

# %%
tree2.fit(df['X'].values.reshape(100,1),df['res2'].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
df.sample(3)
tree2.predict(df[])
# Out:
#            X         y     pred1      res1      res2
# 3   0.098658 -0.070178  0.265458 -0.335636  0.019861
# 81  0.123298  0.069299  0.265458 -0.196159  0.019861
# 78 -0.141534  0.074749  0.265458 -0.190709  0.019861

# %%
df['res2']=df['y'] - df['pred2']

# %%
y_pred3=0.26543 + sum(regressor.predict(X_test.reshape(-1,1)) for regressor in [clf2 ,tree2])

# %%
X_test.shape
# Out:
# (500,)

# %%
sns.scatterplot(df,x='X',y='y')
plt.plot(X_test,y_pred2,color='red',linewidth=2)
