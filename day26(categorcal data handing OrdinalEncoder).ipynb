# %%
import pandas as pd
import numpy as np
df=pd.read_csv("customer.csv")
df.sample(3)
# Out:
#     age gender   review education purchased
# 21   32   Male  Average        PG        No
# 35   74   Male     Poor    School       Yes
# 11   74   Male     Good        UG       Yes

# %%
df=df.iloc[:,2:]

# %%
df.head(2)
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No

# %%
from sklearn.model_selection import train_test_split

# %%
df.iloc[:,-1:]
# Out:
#    purchased
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# 5        Yes
# 6         No
# 7        Yes
# 8         No
# 9        Yes
# 10       Yes
# 11       Yes
# 12        No
# 13        No
# 14       Yes
# 15        No
# 16       Yes
# 17       Yes
# 18        No
# 19       Yes
# 20       Yes
# 21        No
# 22       Yes
# 23        No
# 24       Yes
# 25        No
# 26        No
# 27        No
# 28        No
# 29       Yes
# 30        No
# 31       Yes
# 32       Yes
# 33       Yes
# 34        No
# 35       Yes
# 36       Yes
# 37       Yes
# 38        No
# 39        No
# 40        No
# 41       Yes
# 42       Yes
# 43        No
# 44        No
# 45       Yes
# 46        No
# 47       Yes
# 48       Yes
# 49        No

# %%
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1:] , test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
one=OrdinalEncoder(categories=[['Poor','Average','Good'] ,['School','UG','PG']])

# %%
one.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_trained=one.transform(x_train)
x_tested=one.transform(x_test)

# %%
x_train
# Out:
#      review education
# 37  Average        PG
# 24  Average        PG
# 10     Good        UG
# 16     Poor        UG
# 34  Average    School
# 21  Average        PG
# 26     Poor        PG
# 29  Average        UG
# 31     Poor    School
# 45     Poor        PG
# 11     Good        UG
# 48     Good        UG
# 38     Good    School
# 7      Poor    School
# 18     Good    School
# 33     Good        PG
# 2      Good        PG
# 42     Good        PG
# 25     Good    School
# 23     Good    School
# 46     Poor        PG
# 40     Good    School
# 30  Average        UG
# 9      Good        UG
# 0   Average    School
# 22     Poor        PG
# 19     Poor        PG
# 28     Poor    School
# 8   Average        UG
# 15     Poor        UG
# 13  Average    School
# 6      Good    School
# 4   Average        UG
# 49     Good        UG
# 36     Good        UG
# 39     Poor        PG
# 5   Average    School
# 17     Poor        UG
# 14     Poor        PG
# 12     Poor    School

# %%
import seaborn as sns
y_train.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # lable in coding  fro given code

# %% [markdown]
# # used only fro output data

# %%
y_train
# Out:
#     purchased
# 37       True
# 24       True
# 10       True
# 16       True
# 34       True
# 21       True
# 26       True
# 29       True
# 31       True
# 45       True
# 11       True
# 48       True
# 38       True
# 7        True
# 18       True
# 33       True
# 2        True
# 42       True
# 25       True
# 23       True
# 46       True
# 40       True
# 30       True
# 9        True
# 0        True
# 22       True
# 19       True
# 28       True
# 8        True
# 15       True
# 13       True
# 6        True
# 4        True
# 49       True
# 36       True
# 39       True
# 5        True
# 17       True
# 14       True
# 12       True

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(y_train)
# Out:
# C:\Users\raj\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train=pd.DataFrame(y_train,dtype=bool)

# %%
y_train.sample(10)
# Out:
#     purchased
# 0        True
# 17       True
# 39       True
# 19       True
# 28       True
# 29       True
# 11       True
# 37       True
# 21       True
# 15       True

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
