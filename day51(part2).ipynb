# %%
import pandas as pd
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=100 , n_features=1 , n_informative=1 , n_targets=1 , noise=20 ,random_state=13 )

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
# Out:
# <div id='3cad3d41-10dd-4aac-84fc-79bcfe9ded22'></div>

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
import numpy as np
# Out:
# [27.82809103]
# -2.29474455867698

# %%
m=27.82
class GBRegressor:
    def __init__(self,learning_rate,epochs):
        self.m=27.82
        self.b=-120
        self.lr=learning_rate
        self.epochs = epochs
    def fit(self,x,y):
        # calulated the Gradient decent
        for i in range(self.epochs):
             loss_slope_b = -2 * np.sum(y - self.m*x.ravel() - self.b)
            
             self.b = self.b - (self.lr * loss_slope_b)
             print(loss_slope_b,self.b)

# %%
gd=GBRegressor(0.001,100)

# %%
#gd.fit(x,y)

# %%
gd2=GBRegressor(0.01,10)

# %%
gd2.fit(x,y) #it's takeng long jumps get towords the solution so it skeps the solution
# Out:
# -23541.145603484838 115.41145603484838
# 23541.145603484834 -119.99999999999997
# -23541.145603484834 115.41145603484838
# 23541.145603484834 -119.99999999999997
# -23541.145603484834 115.41145603484838
# 23541.145603484834 -119.99999999999997
# -23541.145603484834 115.41145603484838
# 23541.145603484834 -119.99999999999997
# -23541.145603484834 115.41145603484838
# 23541.145603484834 -119.99999999999997

# %%
from sklearn.model_selection import cross_val_score

# %%
np.mean(cross_val_score(lr,x,y,scoring='r2',cv=10))
# Out:
# 0.6375011587464419

# %% [markdown]
# # b is not canstant amd m is not constant

# %%
import pandas as pd
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=100 , n_features=1 , n_informative=1 , n_targets=1 , noise=20 ,random_state=13 )

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
# Out:
# <div id='f35ea650-0b62-4ba9-8589-5c0edc9eda21'></div>

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
import numpy as np
# Out:
# [27.82809103]
# -2.29474455867698

# %%
class GBRegressor:
    def __init__(self,learning_rate,epochs):
        self.m=100
        self.b=-120
        self.lr=learning_rate
        self.epochs = epochs
    def fit(self,x,y):
        # calulated the Gradient decent
        for i in range(self.epochs):
             loss_slope_b = -2 * np.sum(y - self.m*x.ravel() - self.b)
             loss_slope_m = -2 * np.sum((y - self.m*x.ravel() - self.b)*x.ravel())
            
             self.b = self.b - (self.lr * loss_slope_b)
             self.m = self.m - (self.lr * loss_slope_m)
        print(self.m,self.b)
    def predict(self,x):
        return self.m * X + self.b

# %%
grdc= GBRegressor(0.001,100)

# %%
grdc.fit(x,y)
# Out:
# 88.7901778060777 -97.30202349511147
# 79.26989400677363 -79.01269499728718
# 71.19603915550572 -64.2700212110887
# 64.357826042914 -52.381567622457695
# 58.573134285938856 -42.79092431395032
# 53.685100591058074 -35.05083591632167
# 49.55898969983806 -28.80166573902754
# 46.07935938462746 -23.754130522644466
# 43.14751810732243 -19.6754551237646
# 40.679264258689464 -16.378266564607884
# 38.602889878179504 -13.711682863685132
# 36.85742837440565 -11.55416078082497
# 35.391124246007365 -9.807753543980294
# 34.160102562818395 -8.393499154751025
# 33.12721658147269 -7.2477154903755485
# 32.2610530264308 -6.3190229237706514
# 31.53507604240516 -5.5659507997754325
# 30.926892458014258 -4.955012616245335
# 30.417622682493505 -4.459157586120731
# 29.991363212652477 -4.056524538225423
# 29.63472830753753 -3.7294387591921634
# 29.33645986404345 -3.4636041130856206
# 29.087095882238803 -3.2474521798712006
# 28.87868913818444 -3.071617693375023
# 28.70456878480573 -2.928515605334555
# ...

# %%
grdc.fit(x,y)
# Out:
# 27.828091032520142 -2.2947445586769826

# %%
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
b = -520
m = 600
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(x.shape[0]):
        slope_b = slope_b - 2*(y[j] - (m * x[j]) -  b)
        slope_m = slope_m - 2*(y[j] - (m * x[j]) -  b)*x[j]
        cost = cost + (y[j] - m * x[j] -b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(0, 4500000)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_cost[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation5.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)
# Out:
# <div id='3a031a04-ee9d-4caa-b909-9bb3723f73f2'></div>
